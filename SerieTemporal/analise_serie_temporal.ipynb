# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv("porto_rio_grande_total.csv")
df.head()
# Out:
#          Data     Peso_KG
# 0  2015-01-01  1893541169
# 1  2015-02-01  1534283501
# 2  2015-03-01  2103836966
# 3  2015-04-01  4898645070
# 4  2015-05-01  3986192070

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Data     132 non-null    str
#  1   Peso_KG  132 non-null    int64
# dtypes: int64(1), str(1)
# memory usage: 2.2 KB

# %%
df.Data = pd.to_datetime(df.Data)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Data     132 non-null    datetime64[us]
#  1   Peso_KG  132 non-null    int64
# dtypes: datetime64[us](1), int64(1)
# memory usage: 2.2 KB

# %%
df.set_index("Data", inplace=True)

# %%
df.head()
# Out:
#                Peso_KG
# Data
# 2015-01-01  1893541169
# 2015-02-01  1534283501
# 2015-03-01  2103836966
# 2015-04-01  4898645070
# 2015-05-01  3986192070

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 132 entries, 2015-01-01 to 2025-12-01
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Peso_KG  132 non-null    int64
# dtypes: int64(1)
# memory usage: 2.1 KB

# %%
df.plot()
# Out:
# <Axes: xlabel='Data'>

# %%
df.rolling(12).mean().plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Data'>

# %%
df.groupby(df.index.year).sum().plot()
# Out:
# <Axes: xlabel='Data'>

# %%
plt.plot(df.diff())

# %%
from statsmodels.tsa.stattools import adfuller
# Selecionando o fechamento do Ibovespa
# Aplicando o teste ADF
resultado = adfuller(df)
# Resultados
print("Estatística ADF:", resultado[0])
print("p-valor:", resultado[1])
# Out:
# Estatística ADF: -3.176590673182596
# p-valor: 0.02138032256670097

# %%
filtro = (df.index.year >= 2016) & (df.index.year <= 2018)
df[filtro].diff().plot()
# Out:
# <Axes: xlabel='Data'>

# %%
filtro = (df.index.year >= 2018) & (df.index.year <= 2020)
df[filtro].diff().plot()
# Out:
# <Axes: xlabel='Data'>

# %%
filtro = (df.index.year == 2017) 
df[filtro].diff().plot()
# Out:
# <Axes: xlabel='Data'>

# %%
filtro = (df.index.year == 2018) 
df[filtro].diff().plot()
# Out:
# <Axes: xlabel='Data'>

# %%
filtro = (df.index.year == 2019) 
df[filtro].diff().plot()
# Out:
# <Axes: xlabel='Data'>

# %%
filtro = (df.index.year == 2020) 
df[filtro].diff().plot()
# Out:
# <Axes: xlabel='Data'>

# %%
filtro = (df.index.year == 2021) 
df[filtro].diff().plot()
# Out:
# <Axes: xlabel='Data'>

# %%
filtro = (df.index.year == 2022) 
df[filtro].diff().plot()
# Out:
# <Axes: xlabel='Data'>

# %%
filtro = (df.index.year == 2023) 
df[filtro].diff().plot()
# Out:
# <Axes: xlabel='Data'>
